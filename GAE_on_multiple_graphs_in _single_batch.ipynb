# %%
""" This is graph autoencoder.
The autoencoder is trained taking as input many graphs.
The learned task of the autoencoder is to reconstruct a given molecule. """

import pandas as pd

# Read in the data
drug_data=pd.read_csv("BBBP.csv")

#sum all values equal to 1 in p_np column of drug_data
total_unitary_pnp = sum(drug_data.p_np==1)
print ("Total number of unitary p_np values: ", total_unitary_pnp)

#sum all values equal to 0 in p_np column of drug_data
total_zero_pnp = sum(drug_data.p_np==0)
print ("Total number of zero p_np values: ", total_zero_pnp)

# Print the total number of p_np values
print ("Total number of p_np values: ", len(drug_data.p_np))

# Calculate the percentage of unitary p_np values
print ("Percentage of unitary p_np values: ", round(total_unitary_pnp*100/len(drug_data.p_np),2), "%")

#calculate the percentage of zero p_np values
print ("Percentage of zero p_np values: ", round (total_zero_pnp*100/len(drug_data.p_np),2), "%")
# Out:
# Total number of unitary p_np values:  1567
# Total number of zero p_np values:  483
# Total number of p_np values:  2050
# Percentage of unitary p_np values:  76.44 %
# Percentage of zero p_np values:  23.56 %

# %% [markdown]
# # Creating images from dataset

# %%
from rdkit import Chem
from rdkit import RDLogger
from utils import *
from matplotlib import colors
from rdkit.Chem.Draw import MolToImage

# check the data frame
print(drug_data.head())


#extract smiles from the data frame and check the first 10 smiles
smiles = drug_data['smiles']
smiles.head()

#convert smiles to mols and disable warnings
RDLogger.DisableLog('rdApp.*')
mols = [Chem.MolFromSmiles(s) for s in smiles]
mols
#print (type(mols[0]))

#resizing the drug_data to 
end_of_array = len (drug_data)
smiles=smiles[:end_of_array]
#print(smiles)

for i in range(0, len(smiles)):
    if smiles[i] == None:
        print(i)
# Create a graph representation of the first molecule
for i in range(0, end_of_array):
    name = drug_data['name'][i]
    if mols[i] != None:
        try: img = get_image(mols[i],None , name)
        except : print("un'immagine non è stata salvata")
# Out:
#    num                  name  p_np  \
# 0    1            Propanolol     1
# 1    2  Terbutylchlorambucil     1
# 2    3                 40730     1
# 3    4                    24     1
# 4    5           cloxacillin     1
#
#                                               smiles
# 0                   [Cl].CC(C)NCC(O)COc1cccc2ccccc12
# 1           C(=O)(OC(C)(C)C)CCCc1ccc(cc1)N(CCCl)CCCl
# 2  c12c3c(N4CCN(C)CC4)c(F)cc1c(c(C(O)=O)cn2C(C)CO...
# 3                   C1CCN(CC1)Cc1cccc(c1)OCCCNC(=O)C
# 4  Cc1onc(c2ccccc2Cl)c1C(=O)N[C@H]3[C@H]4SC(C)(C)...
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata
# un'immagine non è stata salvata

# %% [markdown]
# # Creating the list of the data

# %%
from torch_geometric.data import DataLoader
import networkx as nx
from torch_geometric.nn import GAE
from torch_geometric.utils import train_test_split_edges
from utils import *


# Load the smiles and create the graph representation
smiles = drug_data['smiles'].to_list()
# Resize the array
smiles = smiles[:end_of_array]
res = [i for i in range(len(smiles)) if smiles[i] == '']
print (res)
# Load the labels we don't want to use them for training the autoencoder
labels = drug_data['p_np'].to_list()
# Resize the array
labels = labels[:end_of_array]

# Create a list of PyTorch Geometric Data objects
data_list = create_pytorch_geometric_graph_data_list_from_smiles_and_labels(smiles, labels)
print ("First object in the data_list: " + str(data_list[0].x.shape))
# Out:
# []
# First object in the data_list: torch.Size([20, 79])

# %% [markdown]
# # Splitting lists of train and tests

# %%
# Split the data into training and test sets
import random
random.shuffle(data_list)
print ("Number of graphs in the data_list: " + str(len(data_list)))
print ("Number of graphs in the training set should be: " + str(int(len(data_list)*0.8)))
print ("Number of graphs in the test set should be: " + str(int(len(data_list)*0.2)))
train_len = int(len(data_list)*0.8)
test_len = int(len(data_list)*0.2)
train = data_list[:train_len] #train set
test = data_list[train_len:] #val set
print ("Number of graphs in the training set: " + str(len(train)))
print ("Number of graphs in the test set: " + str(len(test)))
# Out:
# Number of graphs in the data_list: 2039
# Number of graphs in the training set should be: 1631
# Number of graphs in the test set should be: 407
# Number of graphs in the training set: 1631
# Number of graphs in the test set: 408

# %% [markdown]
# # Creating the dataloader from training data

# %%
from torch_geometric.loader import DataLoader
# imposing batch size
batch_size = len(train)
dataloader = DataLoader(dataset=train, batch_size=batch_size)

# %% [markdown]
# # Encoder for the GAE

# %%
# Defining the model encoder
class GCNEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(GCNEncoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True) # cached only for transductive learning
        self.conv2 = GCNConv(2 * out_channels, out_channels, cached=True) # cached only for transductive learning
    
    # the forward function defines the computation performed at every call
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv2(x, edge_index)

# %% [markdown]
# # GAE model definition
#
# The encoder has to be given as an input for the GAE. The encoder must have a forward function

# %%
from torch_geometric.nn import GCNConv, GAE
from torch_geometric.nn import GCNConv, GAE, GATConv, Linear, to_hetero


# parameters for the model
out_channels = 2
print ("The dimension of the output from the encoder part: " + str(out_channels))
num_features = 79
print ("Num of the features: " + str(num_features))

# Create the model
model = GAE(GCNEncoder(num_features, out_channels))
# Out:
# The dimension of the output from the encoder part: 2
# Num of the features: 79

# %% [markdown]
# # Defining the training part

# %%
from torch_geometric.utils import scatter
from torch_geometric.loader import DataLoader
from torch.utils.tensorboard import SummaryWriter

epochs = 1000
print ("Num of the epochs: " + str(epochs))

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
graph_batch = next(iter(dataloader))

for epoch in range(1, epochs + 1):
   
    # Zero the gradients
    optimizer.zero_grad()
    
    graph_batch = graph_batch.to(device)
    
    batch_size = graph_batch.batch.max().item() + 1
    print ("This is the batch size: " + str(batch_size))
    print (graph_batch)
    out = model.encode(graph_batch.x, graph_batch.edge_index)
    loss = model.recon_loss(out, graph_batch.edge_index)
    
    # Backward pass and optimization
    loss.backward()
    optimizer.step()
    
    # Logging
    if (i + 1) % 10 == 0:
        print("Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}"
            .format(epoch + 1, 100, i + 1, len(dataloader), loss.item()))
# Out:
# Num of the epochs: 1000
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [2/100], Step [2050/1], Loss: 1.3683
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [3/100], Step [2050/1], Loss: 1.3579
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [4/100], Step [2050/1], Loss: 1.3491
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [5/100], Step [2050/1], Loss: 1.3378
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [6/100], Step [2050/1], Loss: 1.3244
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [7/100], Step [2050/1], Loss: 1.3088
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [8/100], Step [2050/1], Loss: 1.2913
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [9/100], Step [2050/1], Loss: 1.2747
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [10/100], Step [2050/1], Loss: 1.2614
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [11/100], Step [2050/1], Loss: 1.2448
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [12/100], Step [2050/1], Loss: 1.2321
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [13/100], Step [2050/1], Loss: 1.2187
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [14/100], Step [2050/1], Loss: 1.2065
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [15/100], Step [2050/1], Loss: 1.2010
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [16/100], Step [2050/1], Loss: 1.1913
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [17/100], Step [2050/1], Loss: 1.1921
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [18/100], Step [2050/1], Loss: 1.1935
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [19/100], Step [2050/1], Loss: 1.1917
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [20/100], Step [2050/1], Loss: 1.1942
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [21/100], Step [2050/1], Loss: 1.1959
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [22/100], Step [2050/1], Loss: 1.2005
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [23/100], Step [2050/1], Loss: 1.1970
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [24/100], Step [2050/1], Loss: 1.1945
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [25/100], Step [2050/1], Loss: 1.1929
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [26/100], Step [2050/1], Loss: 1.1824
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [27/100], Step [2050/1], Loss: 1.1801
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [28/100], Step [2050/1], Loss: 1.1789
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [29/100], Step [2050/1], Loss: 1.1705
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [30/100], Step [2050/1], Loss: 1.1696
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [31/100], Step [2050/1], Loss: 1.1683
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [32/100], Step [2050/1], Loss: 1.1649
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [33/100], Step [2050/1], Loss: 1.1628
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [34/100], Step [2050/1], Loss: 1.1621
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [35/100], Step [2050/1], Loss: 1.1581
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [36/100], Step [2050/1], Loss: 1.1568
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [37/100], Step [2050/1], Loss: 1.1527
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [38/100], Step [2050/1], Loss: 1.1463
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [39/100], Step [2050/1], Loss: 1.1429
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [40/100], Step [2050/1], Loss: 1.1370
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [41/100], Step [2050/1], Loss: 1.1324
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [42/100], Step [2050/1], Loss: 1.1256
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [43/100], Step [2050/1], Loss: 1.1231
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [44/100], Step [2050/1], Loss: 1.1215
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [45/100], Step [2050/1], Loss: 1.1152
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [46/100], Step [2050/1], Loss: 1.1130
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [47/100], Step [2050/1], Loss: 1.1126
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [48/100], Step [2050/1], Loss: 1.1069
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [49/100], Step [2050/1], Loss: 1.1073
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [50/100], Step [2050/1], Loss: 1.1066
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [51/100], Step [2050/1], Loss: 1.1048
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [52/100], Step [2050/1], Loss: 1.1091
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [53/100], Step [2050/1], Loss: 1.1040
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [54/100], Step [2050/1], Loss: 1.1063
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [55/100], Step [2050/1], Loss: 1.1081
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [56/100], Step [2050/1], Loss: 1.1050
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [57/100], Step [2050/1], Loss: 1.1065
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [58/100], Step [2050/1], Loss: 1.1074
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [59/100], Step [2050/1], Loss: 1.1074
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [60/100], Step [2050/1], Loss: 1.1061
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [61/100], Step [2050/1], Loss: 1.1022
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [62/100], Step [2050/1], Loss: 1.1036
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [63/100], Step [2050/1], Loss: 1.1028
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [64/100], Step [2050/1], Loss: 1.1027
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [65/100], Step [2050/1], Loss: 1.1027
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [66/100], Step [2050/1], Loss: 1.0973
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [67/100], Step [2050/1], Loss: 1.0971
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [68/100], Step [2050/1], Loss: 1.1011
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [69/100], Step [2050/1], Loss: 1.0987
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [70/100], Step [2050/1], Loss: 1.1007
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [71/100], Step [2050/1], Loss: 1.0943
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [72/100], Step [2050/1], Loss: 1.1011
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [73/100], Step [2050/1], Loss: 1.0986
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [74/100], Step [2050/1], Loss: 1.0980
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [75/100], Step [2050/1], Loss: 1.0986
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [76/100], Step [2050/1], Loss: 1.0991
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [77/100], Step [2050/1], Loss: 1.0984
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [78/100], Step [2050/1], Loss: 1.1005
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [79/100], Step [2050/1], Loss: 1.1002
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [80/100], Step [2050/1], Loss: 1.0968
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [81/100], Step [2050/1], Loss: 1.0960
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [82/100], Step [2050/1], Loss: 1.0945
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [83/100], Step [2050/1], Loss: 1.0977
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [84/100], Step [2050/1], Loss: 1.1013
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [85/100], Step [2050/1], Loss: 1.0944
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [86/100], Step [2050/1], Loss: 1.0963
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [87/100], Step [2050/1], Loss: 1.0992
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [88/100], Step [2050/1], Loss: 1.0965
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [89/100], Step [2050/1], Loss: 1.0959
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [90/100], Step [2050/1], Loss: 1.0948
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [91/100], Step [2050/1], Loss: 1.0976
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [92/100], Step [2050/1], Loss: 1.0954
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [93/100], Step [2050/1], Loss: 1.0967
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [94/100], Step [2050/1], Loss: 1.0948
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [95/100], Step [2050/1], Loss: 1.0970
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [96/100], Step [2050/1], Loss: 1.0965
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [97/100], Step [2050/1], Loss: 1.0928
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [98/100], Step [2050/1], Loss: 1.0928
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [99/100], Step [2050/1], Loss: 1.0902
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [100/100], Step [2050/1], Loss: 1.0914
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [101/100], Step [2050/1], Loss: 1.0893
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [102/100], Step [2050/1], Loss: 1.0941
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [103/100], Step [2050/1], Loss: 1.0922
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [104/100], Step [2050/1], Loss: 1.0939
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [105/100], Step [2050/1], Loss: 1.0962
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [106/100], Step [2050/1], Loss: 1.0910
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [107/100], Step [2050/1], Loss: 1.0947
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [108/100], Step [2050/1], Loss: 1.0940
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [109/100], Step [2050/1], Loss: 1.0901
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [110/100], Step [2050/1], Loss: 1.0944
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [111/100], Step [2050/1], Loss: 1.0920
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [112/100], Step [2050/1], Loss: 1.0934
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [113/100], Step [2050/1], Loss: 1.0880
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [114/100], Step [2050/1], Loss: 1.0884
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [115/100], Step [2050/1], Loss: 1.0918
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [116/100], Step [2050/1], Loss: 1.0900
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [117/100], Step [2050/1], Loss: 1.0913
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [118/100], Step [2050/1], Loss: 1.0898
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [119/100], Step [2050/1], Loss: 1.0906
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [120/100], Step [2050/1], Loss: 1.0879
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [121/100], Step [2050/1], Loss: 1.0900
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [122/100], Step [2050/1], Loss: 1.0914
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [123/100], Step [2050/1], Loss: 1.0879
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [124/100], Step [2050/1], Loss: 1.0843
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [125/100], Step [2050/1], Loss: 1.0894
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [126/100], Step [2050/1], Loss: 1.0902
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [127/100], Step [2050/1], Loss: 1.0860
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [128/100], Step [2050/1], Loss: 1.0885
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [129/100], Step [2050/1], Loss: 1.0899
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [130/100], Step [2050/1], Loss: 1.0903
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [131/100], Step [2050/1], Loss: 1.0891
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [132/100], Step [2050/1], Loss: 1.0853
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [133/100], Step [2050/1], Loss: 1.0876
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [134/100], Step [2050/1], Loss: 1.0902
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [135/100], Step [2050/1], Loss: 1.0854
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [136/100], Step [2050/1], Loss: 1.0865
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [137/100], Step [2050/1], Loss: 1.0882
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [138/100], Step [2050/1], Loss: 1.0894
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [139/100], Step [2050/1], Loss: 1.0876
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [140/100], Step [2050/1], Loss: 1.0858
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [141/100], Step [2050/1], Loss: 1.0850
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [142/100], Step [2050/1], Loss: 1.0895
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [143/100], Step [2050/1], Loss: 1.0867
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [144/100], Step [2050/1], Loss: 1.0847
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [145/100], Step [2050/1], Loss: 1.0867
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [146/100], Step [2050/1], Loss: 1.0845
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [147/100], Step [2050/1], Loss: 1.0829
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [148/100], Step [2050/1], Loss: 1.0826
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [149/100], Step [2050/1], Loss: 1.0871
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [150/100], Step [2050/1], Loss: 1.0829
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [151/100], Step [2050/1], Loss: 1.0888
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [152/100], Step [2050/1], Loss: 1.0822
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [153/100], Step [2050/1], Loss: 1.0871
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [154/100], Step [2050/1], Loss: 1.0849
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [155/100], Step [2050/1], Loss: 1.0853
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [156/100], Step [2050/1], Loss: 1.0828
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [157/100], Step [2050/1], Loss: 1.0859
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [158/100], Step [2050/1], Loss: 1.0879
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [159/100], Step [2050/1], Loss: 1.0833
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [160/100], Step [2050/1], Loss: 1.0872
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [161/100], Step [2050/1], Loss: 1.0849
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [162/100], Step [2050/1], Loss: 1.0820
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [163/100], Step [2050/1], Loss: 1.0832
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [164/100], Step [2050/1], Loss: 1.0832
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [165/100], Step [2050/1], Loss: 1.0815
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [166/100], Step [2050/1], Loss: 1.0835
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [167/100], Step [2050/1], Loss: 1.0835
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [168/100], Step [2050/1], Loss: 1.0854
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [169/100], Step [2050/1], Loss: 1.0828
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [170/100], Step [2050/1], Loss: 1.0807
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [171/100], Step [2050/1], Loss: 1.0858
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [172/100], Step [2050/1], Loss: 1.0845
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [173/100], Step [2050/1], Loss: 1.0818
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [174/100], Step [2050/1], Loss: 1.0826
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [175/100], Step [2050/1], Loss: 1.0823
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [176/100], Step [2050/1], Loss: 1.0807
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [177/100], Step [2050/1], Loss: 1.0803
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [178/100], Step [2050/1], Loss: 1.0827
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [179/100], Step [2050/1], Loss: 1.0805
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [180/100], Step [2050/1], Loss: 1.0826
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [181/100], Step [2050/1], Loss: 1.0808
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [182/100], Step [2050/1], Loss: 1.0788
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [183/100], Step [2050/1], Loss: 1.0814
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [184/100], Step [2050/1], Loss: 1.0817
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [185/100], Step [2050/1], Loss: 1.0854
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [186/100], Step [2050/1], Loss: 1.0792
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [187/100], Step [2050/1], Loss: 1.0791
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [188/100], Step [2050/1], Loss: 1.0789
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [189/100], Step [2050/1], Loss: 1.0816
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [190/100], Step [2050/1], Loss: 1.0818
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [191/100], Step [2050/1], Loss: 1.0785
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [192/100], Step [2050/1], Loss: 1.0798
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [193/100], Step [2050/1], Loss: 1.0785
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [194/100], Step [2050/1], Loss: 1.0804
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [195/100], Step [2050/1], Loss: 1.0787
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [196/100], Step [2050/1], Loss: 1.0786
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [197/100], Step [2050/1], Loss: 1.0798
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [198/100], Step [2050/1], Loss: 1.0824
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [199/100], Step [2050/1], Loss: 1.0794
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [200/100], Step [2050/1], Loss: 1.0756
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [201/100], Step [2050/1], Loss: 1.0812
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [202/100], Step [2050/1], Loss: 1.0811
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [203/100], Step [2050/1], Loss: 1.0779
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [204/100], Step [2050/1], Loss: 1.0796
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [205/100], Step [2050/1], Loss: 1.0803
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [206/100], Step [2050/1], Loss: 1.0791
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [207/100], Step [2050/1], Loss: 1.0790
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [208/100], Step [2050/1], Loss: 1.0797
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [209/100], Step [2050/1], Loss: 1.0802
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [210/100], Step [2050/1], Loss: 1.0759
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [211/100], Step [2050/1], Loss: 1.0782
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [212/100], Step [2050/1], Loss: 1.0784
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [213/100], Step [2050/1], Loss: 1.0800
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [214/100], Step [2050/1], Loss: 1.0782
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [215/100], Step [2050/1], Loss: 1.0777
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [216/100], Step [2050/1], Loss: 1.0752
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [217/100], Step [2050/1], Loss: 1.0782
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [218/100], Step [2050/1], Loss: 1.0769
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [219/100], Step [2050/1], Loss: 1.0785
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [220/100], Step [2050/1], Loss: 1.0751
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [221/100], Step [2050/1], Loss: 1.0796
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [222/100], Step [2050/1], Loss: 1.0784
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [223/100], Step [2050/1], Loss: 1.0786
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [224/100], Step [2050/1], Loss: 1.0782
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [225/100], Step [2050/1], Loss: 1.0781
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [226/100], Step [2050/1], Loss: 1.0758
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [227/100], Step [2050/1], Loss: 1.0736
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [228/100], Step [2050/1], Loss: 1.0791
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [229/100], Step [2050/1], Loss: 1.0787
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [230/100], Step [2050/1], Loss: 1.0830
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [231/100], Step [2050/1], Loss: 1.0787
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [232/100], Step [2050/1], Loss: 1.0788
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [233/100], Step [2050/1], Loss: 1.0793
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [234/100], Step [2050/1], Loss: 1.0789
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [235/100], Step [2050/1], Loss: 1.0775
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [236/100], Step [2050/1], Loss: 1.0793
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [237/100], Step [2050/1], Loss: 1.0741
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [238/100], Step [2050/1], Loss: 1.0798
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [239/100], Step [2050/1], Loss: 1.0766
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [240/100], Step [2050/1], Loss: 1.0769
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [241/100], Step [2050/1], Loss: 1.0795
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [242/100], Step [2050/1], Loss: 1.0774
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [243/100], Step [2050/1], Loss: 1.0749
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [244/100], Step [2050/1], Loss: 1.0763
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [245/100], Step [2050/1], Loss: 1.0760
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [246/100], Step [2050/1], Loss: 1.0778
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [247/100], Step [2050/1], Loss: 1.0744
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [248/100], Step [2050/1], Loss: 1.0817
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [249/100], Step [2050/1], Loss: 1.0809
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [250/100], Step [2050/1], Loss: 1.0800
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [251/100], Step [2050/1], Loss: 1.0764
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [252/100], Step [2050/1], Loss: 1.0748
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [253/100], Step [2050/1], Loss: 1.0775
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [254/100], Step [2050/1], Loss: 1.0784
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [255/100], Step [2050/1], Loss: 1.0751
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [256/100], Step [2050/1], Loss: 1.0751
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [257/100], Step [2050/1], Loss: 1.0751
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [258/100], Step [2050/1], Loss: 1.0789
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [259/100], Step [2050/1], Loss: 1.0778
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [260/100], Step [2050/1], Loss: 1.0770
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [261/100], Step [2050/1], Loss: 1.0765
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [262/100], Step [2050/1], Loss: 1.0799
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [263/100], Step [2050/1], Loss: 1.0753
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [264/100], Step [2050/1], Loss: 1.0797
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [265/100], Step [2050/1], Loss: 1.0753
# This is the batch size: 1631
# ...
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [914/100], Step [2050/1], Loss: 1.0653
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [915/100], Step [2050/1], Loss: 1.0678
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [916/100], Step [2050/1], Loss: 1.0680
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [917/100], Step [2050/1], Loss: 1.0672
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [918/100], Step [2050/1], Loss: 1.0673
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [919/100], Step [2050/1], Loss: 1.0644
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [920/100], Step [2050/1], Loss: 1.0660
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [921/100], Step [2050/1], Loss: 1.0681
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [922/100], Step [2050/1], Loss: 1.0665
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [923/100], Step [2050/1], Loss: 1.0659
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [924/100], Step [2050/1], Loss: 1.0625
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [925/100], Step [2050/1], Loss: 1.0661
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [926/100], Step [2050/1], Loss: 1.0652
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [927/100], Step [2050/1], Loss: 1.0711
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [928/100], Step [2050/1], Loss: 1.0646
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [929/100], Step [2050/1], Loss: 1.0660
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [930/100], Step [2050/1], Loss: 1.0639
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [931/100], Step [2050/1], Loss: 1.0687
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [932/100], Step [2050/1], Loss: 1.0648
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [933/100], Step [2050/1], Loss: 1.0680
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [934/100], Step [2050/1], Loss: 1.0670
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [935/100], Step [2050/1], Loss: 1.0683
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [936/100], Step [2050/1], Loss: 1.0657
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [937/100], Step [2050/1], Loss: 1.0668
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [938/100], Step [2050/1], Loss: 1.0651
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [939/100], Step [2050/1], Loss: 1.0646
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [940/100], Step [2050/1], Loss: 1.0690
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [941/100], Step [2050/1], Loss: 1.0671
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [942/100], Step [2050/1], Loss: 1.0652
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [943/100], Step [2050/1], Loss: 1.0668
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [944/100], Step [2050/1], Loss: 1.0666
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [945/100], Step [2050/1], Loss: 1.0671
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [946/100], Step [2050/1], Loss: 1.0638
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [947/100], Step [2050/1], Loss: 1.0662
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [948/100], Step [2050/1], Loss: 1.0680
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [949/100], Step [2050/1], Loss: 1.0655
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [950/100], Step [2050/1], Loss: 1.0643
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [951/100], Step [2050/1], Loss: 1.0667
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [952/100], Step [2050/1], Loss: 1.0633
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [953/100], Step [2050/1], Loss: 1.0679
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [954/100], Step [2050/1], Loss: 1.0648
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [955/100], Step [2050/1], Loss: 1.0655
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [956/100], Step [2050/1], Loss: 1.0669
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [957/100], Step [2050/1], Loss: 1.0675
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [958/100], Step [2050/1], Loss: 1.0679
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [959/100], Step [2050/1], Loss: 1.0641
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [960/100], Step [2050/1], Loss: 1.0664
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [961/100], Step [2050/1], Loss: 1.0682
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [962/100], Step [2050/1], Loss: 1.0653
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [963/100], Step [2050/1], Loss: 1.0661
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [964/100], Step [2050/1], Loss: 1.0661
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [965/100], Step [2050/1], Loss: 1.0655
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [966/100], Step [2050/1], Loss: 1.0658
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [967/100], Step [2050/1], Loss: 1.0680
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [968/100], Step [2050/1], Loss: 1.0644
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [969/100], Step [2050/1], Loss: 1.0639
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [970/100], Step [2050/1], Loss: 1.0655
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [971/100], Step [2050/1], Loss: 1.0690
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [972/100], Step [2050/1], Loss: 1.0649
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [973/100], Step [2050/1], Loss: 1.0653
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [974/100], Step [2050/1], Loss: 1.0676
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [975/100], Step [2050/1], Loss: 1.0673
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [976/100], Step [2050/1], Loss: 1.0653
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [977/100], Step [2050/1], Loss: 1.0674
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [978/100], Step [2050/1], Loss: 1.0693
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [979/100], Step [2050/1], Loss: 1.0669
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [980/100], Step [2050/1], Loss: 1.0643
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [981/100], Step [2050/1], Loss: 1.0689
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [982/100], Step [2050/1], Loss: 1.0685
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [983/100], Step [2050/1], Loss: 1.0641
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [984/100], Step [2050/1], Loss: 1.0677
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [985/100], Step [2050/1], Loss: 1.0656
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [986/100], Step [2050/1], Loss: 1.0663
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [987/100], Step [2050/1], Loss: 1.0659
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [988/100], Step [2050/1], Loss: 1.0666
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [989/100], Step [2050/1], Loss: 1.0677
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [990/100], Step [2050/1], Loss: 1.0669
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [991/100], Step [2050/1], Loss: 1.0641
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [992/100], Step [2050/1], Loss: 1.0687
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [993/100], Step [2050/1], Loss: 1.0643
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [994/100], Step [2050/1], Loss: 1.0650
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [995/100], Step [2050/1], Loss: 1.0655
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [996/100], Step [2050/1], Loss: 1.0635
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [997/100], Step [2050/1], Loss: 1.0655
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [998/100], Step [2050/1], Loss: 1.0647
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [999/100], Step [2050/1], Loss: 1.0662
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [1000/100], Step [2050/1], Loss: 1.0639
# This is the batch size: 1631
# DataBatch(x=[39064, 79], edge_index=[2, 84250], edge_attr=[84250, 10], y=[1631], batch=[39064], ptr=[1632])
# Epoch [1001/100], Step [2050/1], Loss: 1.0651

# %% [markdown]
# # Whatching the embedding

# %%
from matplotlib import pyplot as plt
Z= model.encode(graph_batch.x, graph_batch.edge_index)
print ("The type of Z is: " + str(Z))
print ("The shape of Z is: " + str(Z.shape))
plt.plot (Z.detach().numpy()[:,0], Z.detach().numpy()[:,1], 'o')
# Out:
# The type of Z is: tensor([[ 0.2642, -0.7532],
#         [ 0.4697, -1.1487],
#         [ 0.2642, -0.7532],
#         ...,
#         [ 0.9799, -1.0116],
#         [ 0.8563, -1.0609],
#         [ 0.5541, -0.8183]], grad_fn=<AddBackward0>)
# The shape of Z is: torch.Size([39064, 2])
